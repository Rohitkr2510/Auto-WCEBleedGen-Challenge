# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 11.4 MB/s eta 0:00:00
# ...

# %%
import os

# Define the path to your code directory
code_directory = '/content/drive/MyDrive/Sem_VII_project/datasets/'

# Change the current working directory to your code directory
os.chdir(code_directory)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# %%
model.train(data="/content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/data.yaml", epochs=50)  # train the model
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Export the model to ONNX format
success = model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.0.193 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.30GHz)
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 18.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 12.1s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.1 opset 17...
# ONNX: export success ✅ 13.3s, saved as 'runs/detect/train/weights/best.onnx' (11.7 MB)
#
# Export complete (16.5s)
# Results saved to /content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/runs/detect/train/weights
# Predict:         yolo predict task=detect model=runs/detect/train/weights/best.onnx imgsz=640
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/drive/MyDrive/Sem_VII_project/datasets

# %%
from IPython.display import display, Image

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					   train_batch1.jpg
# confusion_matrix_normalized.png			   train_batch2640.jpg
# confusion_matrix.png				   train_batch2641.jpg
# events.out.tfevents.1696527873.dd04df080c1b.438.0  train_batch2642.jpg
# F1_curve.png					   train_batch2.jpg
# labels_correlogram.jpg				   val_batch0_labels.jpg
# labels.jpg					   val_batch0_pred.jpg
# P_curve.png					   val_batch1_labels.jpg
# PR_curve.png					   val_batch1_pred.jpg
# R_curve.png					   val_batch2_labels.jpg
# results.csv					   val_batch2_pred.jpg
# results.png					   weights
# train_batch0.jpg

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data=val.yaml
# Out:
# Ultralytics YOLOv8.0.195 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (AMD EPYC 7B12)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# ...
# 100% 755k/755k [00:00<00:00, 82.0MB/s]
# val: Scanning /content/drive/MyDrive/Sem_VII_project/datasets/labels... 2094 images, 0 backgrounds, 1058 corrupt: 100% 2094/2094 [16:54<00:00,  2.06it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/Sem_VII_project/datasets/images/img1310.png: ignoring corrupt image/label: labels require 5 columns, 1 columns detected
# val: WARNING ⚠️ /content/drive/MyDrive/Sem_VII_project/datasets/images/img1311.png: ignoring corrupt image/label: labels require 5 columns, 1 columns detected
# val: WARNING ⚠️ /content/drive/MyDrive/Sem_VII_project/datasets/images/img1312.png: ignoring corrupt image/label: labels require 5 columns, 1 columns detected
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/2618 /content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images/img1.png: 640x640 (no detections), 8.7ms
# image 2/2618 /content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images/img10.png: 640x640 2 Bleedings, 8.7ms
# image 3/2618 /content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images/img100.png: 640x640 (no detections), 8.9ms
# image 4/2618 /content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images/img1000.png: 640x640 1 Bleeding, 8.5ms
# image 5/2618 /content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images/img1001.png: 640x640 1 Bleeding, 10.2ms
# image 6/2618 /content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images/img1002.png: 640x640 1 Bleeding, 7.4ms
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.30 source=/content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset1
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/49 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset1/A0000.png: 640x640 (no detections), 15.6ms
# image 2/49 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset1/A0001.png: 640x640 1 Bleeding, 22.8ms
# image 3/49 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset1/A0002.png: 640x640 (no detections), 8.3ms
# image 4/49 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset1/A0003.png: 640x640 (no detections), 9.5ms
# image 5/49 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset1/A0004.png: 640x640 (no detections), 7.7ms
# image 6/49 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset1/A0005.png: 640x640 (no detections), 8.2ms
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset2
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/515 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset2/A0050.png: 640x640 1 Bleeding, 8.8ms
# image 2/515 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset2/A0051.png: 640x640 (no detections), 8.9ms
# image 3/515 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset2/A0052.png: 640x640 1 Bleeding, 11.2ms
# image 4/515 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset2/A0053.png: 640x640 (no detections), 8.7ms
# image 5/515 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset2/A0054.png: 640x640 (no detections), 7.9ms
# image 6/515 /content/drive/MyDrive/Sem_VII_project/Auto-WCEBleedGenTest/TestDataset2/A0055.png: 640x640 (no detections), 8.3ms
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train/weights/best.pt conf=0.25 source='/content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images/img1.png'
# Out:
# Ultralytics YOLOv8.0.194 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Sem_VII_project/WCEBleedGen/datasets/images/img1.png: 640x640 (no detections), 15.1ms
# Speed: 6.8ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
